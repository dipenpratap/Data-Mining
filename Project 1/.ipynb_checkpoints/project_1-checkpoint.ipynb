# %% [markdown]
# # <center>CS 4331 - Data Mining</center>
# ## <center>Spring 2020</center>
# ### <center>Project 1</center>
# #### <center>Joshua Ball | Dipendra Yadav</center>

# %%
# Importing the libraries and dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.cluster import KMeans
import seaborn as sns

# %%
# Reading the data and displaying the first 5 rows
dataset = pd.read_csv("hotel_bookings.csv")
dataset.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Problem Understanding Phase

# %% [markdown]
# ### Problem Objective
#     Traveling is expensive overall, but one of the biggest costs associated with a trip is often the lodging.
#     Studies have suggested that the best time to buy a plane ticket for lower-price options is 70 days in advance.
#     But does the same reasoning apply to hotel rooms?

# %% [markdown]
# ### Can this problem be solved using Data Science?
#     We are using data from https://www.kaggle.com/ekretsch/hotel-booking-dataset to develop a clustering algorithm
#     that can find out the best time of the year to book a hotel room in order to get best prices in the market.

# %% [markdown]
# ## Data Preparation Phase
#     Preparing the data for analysis

# %%
# Checking for null values and datatypes of each attributes
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
#  12  meal                            119390 non-null  object
#  13  country                         118902 non-null  object
#  14  market_segment                  119390 non-null  object
#  15  distribution_channel            119390 non-null  object
#  16  is_repeated_guest               119390 non-null  int64
#  17  previous_cancellations          119390 non-null  int64
#  18  previous_bookings_not_canceled  119390 non-null  int64
#  19  reserved_room_type              119390 non-null  object
#  20  assigned_room_type              119390 non-null  object
#  21  booking_changes                 119390 non-null  int64
#  22  deposit_type                    119390 non-null  object
#  23  agent                           103050 non-null  float64
#  24  company                         6797 non-null    float64
#  25  days_in_waiting_list            119390 non-null  int64
#  26  customer_type                   119390 non-null  object
#  27  adr                             119390 non-null  float64
#  28  required_car_parking_spaces     119390 non-null  int64
#  29  total_of_special_requests       119390 non-null  int64
#  30  reservation_status              119390 non-null  object
#  31  reservation_status_date         119390 non-null  object
# dtypes: float64(4), int64(16), object(12)
# memory usage: 29.1+ MB

# %%
""" Here we can see that data has int, float and object values. First of all we have to represent the object
    values to some numerical values so that we can perform exploratory data analysis. Also, we have to fix
    the NaN values present in the dataset."""
# Out:
# ' Here we can see that data has int, float and object values. First of all we have to represent the object\n    values to some numerical values so that we can perform exploratory data analysis. Also, we have to fix\n    the NaN values present in the dataset.'

# %%
# Just a plot function
def plotter():
    plt.figure(figsize=(30, 16))
    sns.set(font_scale=1.4)

# %%
# Cleaning the dataset (looking for outliers and NaN values)
data_size = dataset.shape
print('The size of the dataset is {}'.format(data_size))


# Checking for NaNs in the dataset
print('The attributes with NaNs are as follows:')
NaNs = pd.DataFrame(dataset.isnull().sum())
NaNs
# Out:
# The size of the dataset is (119390, 32)
# The attributes with NaNs are as follows:
#                                      0
# hotel                                0
# is_canceled                          0
# lead_time                            0
# arrival_date_year                    0
# arrival_date_month                   0
# arrival_date_week_number             0
# arrival_date_day_of_month            0
# stays_in_weekend_nights              0
# stays_in_week_nights                 0
# adults                               0
# children                             4
# babies                               0
# meal                                 0
# country                            488
# market_segment                       0
# distribution_channel                 0
# is_repeated_guest                    0
# previous_cancellations               0
# previous_bookings_not_canceled       0
# reserved_room_type                   0
# assigned_room_type                   0
# booking_changes                      0
# deposit_type                         0
# agent                            16340
# company                         112593
# days_in_waiting_list                 0
# customer_type                        0
# adr                                  0
# required_car_parking_spaces          0
# total_of_special_requests            0
# reservation_status                   0
# reservation_status_date              0

# %% [markdown]
#     Here we can see there are so many instances in attributes in country, agent, and company that carries NaNs. For this project, country, agent, and company columns do not add up to the value or contribute to the fluctuation in the pricing over the year. Therefore, we are going to drop these two columns. However, We would have needed to do some interpolation to fill in these values in the data preparation phase of data mining in case these attributes were important in the formation of clusters for this project.

# %%
dataset = dataset.drop(columns = ['country','agent', 'company','children'])

# Validation of the dataset 
print('The cleaned dataset without NaNs are as follows:')
new_data = pd.DataFrame(dataset.isnull().sum())
new_data
# Out:
# The cleaned dataset without NaNs are as follows:
#                                 0
# hotel                           0
# is_canceled                     0
# lead_time                       0
# arrival_date_year               0
# arrival_date_month              0
# arrival_date_week_number        0
# arrival_date_day_of_month       0
# stays_in_weekend_nights         0
# stays_in_week_nights            0
# adults                          0
# babies                          0
# meal                            0
# market_segment                  0
# distribution_channel            0
# is_repeated_guest               0
# previous_cancellations          0
# previous_bookings_not_canceled  0
# reserved_room_type              0
# assigned_room_type              0
# booking_changes                 0
# deposit_type                    0
# days_in_waiting_list            0
# customer_type                   0
# adr                             0
# required_car_parking_spaces     0
# total_of_special_requests       0
# reservation_status              0
# reservation_status_date         0

# %%
# Now lets check how the data is distributed statistically
dataset.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# max                   53.000000                  31.000000
#
#        stays_in_weekend_nights  stays_in_week_nights         adults  \
# count            119390.000000         119390.000000  119390.000000
# mean                  0.927599              2.500302       1.856403
# std                   0.998613              1.908286       0.579261
# min                   0.000000              0.000000       0.000000
# 25%                   0.000000              1.000000       2.000000
# 50%                   1.000000              2.000000       2.000000
# 75%                   2.000000              3.000000       2.000000
# max                  19.000000             50.000000      55.000000
#
#               babies  is_repeated_guest  previous_cancellations  \
# count  119390.000000      119390.000000           119390.000000
# mean        0.007949           0.031912                0.087118
# std         0.097436           0.175767                0.844336
# min         0.000000           0.000000                0.000000
# 25%         0.000000           0.000000                0.000000
# 50%         0.000000           0.000000                0.000000
# 75%         0.000000           0.000000                0.000000
# max        10.000000           1.000000               26.000000
#
#        previous_bookings_not_canceled  booking_changes  days_in_waiting_list  \
# count                   119390.000000    119390.000000         119390.000000
# mean                         0.137097         0.221124              2.321149
# std                          1.497437         0.652306             17.594721
# min                          0.000000         0.000000              0.000000
# 25%                          0.000000         0.000000              0.000000
# 50%                          0.000000         0.000000              0.000000
# 75%                          0.000000         0.000000              0.000000
# max                         72.000000        21.000000            391.000000
#
#                  adr  required_car_parking_spaces  total_of_special_requests
# count  119390.000000                119390.000000              119390.000000
# mean      101.831122                     0.062518                   0.571363
# std        50.535790                     0.245291                   0.792798
# min        -6.380000                     0.000000                   0.000000
# 25%        69.290000                     0.000000                   0.000000
# 50%        94.575000                     0.000000                   0.000000
# 75%       126.000000                     0.000000                   1.000000
# max      5400.000000                     8.000000                   5.000000

# %%
# Checking the number of instances in each month to have a general idea of when people travel most
dataset.arrival_date_month.value_counts()
# Out:
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: arrival_date_month, dtype: int64

# %% [markdown]
# From above data we can see that the months of August followed by July, May, and October has the most travellers.

# %% [markdown]
# To use linear regression for modelling,its necessary to remove correlated variables to improve your model.One can find correlations using pandas “.corr()” function and can visualize the correlation matrix using a heatmap in seaborn.

# %%
# Representing the data using heatmap before correction
plotter()
data_corr = dataset.corr()
sns.heatmap(data_corr,annot = True,cmap = "YlGnBu")
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1, 'Correlation Heatmap')

# %%
#Calculating average rate paid per total stay by multiplying average daily rate * total time stayed
dataset['rate_per_stay'] = dataset['adr'] * (dataset['stays_in_weekend_nights'] + dataset['stays_in_week_nights'])

# %%
rate_per_stay = dataset['rate_per_stay']
adr = dataset['adr']
month = dataset['arrival_date_month']
day = dataset['arrival_date_day_of_month']
year = dataset['arrival_date_year']
week = dataset['arrival_date_week_number']

# %%
plotter()
sns.lineplot(data = dataset, x = 'arrival_date_month', y = 'adr', hue = 'hotel').set_title("average daily rate")
plt.show()
plotter()
sns.lineplot(data = dataset, x = 'arrival_date_month', y = 'rate_per_stay', hue = 'hotel').set_title("rate_per_stay")
# Out:
# Text(0.5, 1.0, 'rate_per_stay')

# %%
#Graphs show a clear trend where certian months have a higher overall price paid and adr

# %%
#Changing months from str -> int so it is no longer categorical and can be used in clustering model
month_map = {'arrival_date_month':{'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,
             'September':9,'October':10,'November':11,'December':12}}
dataset.replace(month_map,inplace=True)

# %%
# Representing the data using heatmap after correction
plotter()
data_corr = dataset.corr()
sns.heatmap(data_corr,annot = True,cmap = "YlGnBu")
plt.title('Correlation Heatmap after correction')
# Out:
# Text(0.5, 1, 'Correlation Heatmap after correction')

# %% [markdown]
#         ==> Dark shades represents positive correlation while lighter shades represents negative correlation.
#     Here we can infer that “arrival_date_month” has strong positive correlation with “arrival_date_week_number” whereas it has strong negative correlation with “arrival_date_year”. Furthermore,
#     if correlation is zero we can infer there is no linear relationship between these two predictors and it is safe to drop these features in case we will be applying Linear Regression model to the dataset.

# %%
#Next we are removing cases where the customer canceled their reservations
dataset.loc[dataset['is_canceled'] == 1] = np.NaN #Replace row with NaN if it was canceled
dataset = dataset.dropna(); #Remove NaN rows
dataset.reset_index(drop=True);

# %%
plt.figure(figsize=(30, 16))
sns.set(font_scale=1.4)
sns.lineplot(data = dataset, x = 'arrival_date_month', y = 'rate_per_stay', hue = 'hotel').set_title("Cleaned rate per stay")    
#Huge peak in summer months, which is to be expected.
# Out:
# Text(0.5, 1.0, 'Cleaned rate per stay')

# %%
def bar_plotter(x):
    sns.set(style="whitegrid")
    plt.figure(figsize=(30, 16))
    sns.set(font_scale=1.4)
    ax = sns.barplot(x, adr)

# %%
# Plotting the rate_per_stay with respect to days
bar_plotter(day)
plt.title('Average Daily Rates vs Day of the Month')
# Out:
# Text(0.5, 1.0, 'Average Daily Rates vs Day of the Month')

# %%
# Plotting the rate_per_stay with respect to weeks
bar_plotter(week)
plt.title('Average Daily Rates vs Weeks of the Year')
# Out:
# Text(0.5, 1.0, 'Average Daily Rates vs Weeks of the Year')

# %%
# Plotting the rate_per_stay with respect to months
bar_plotter(month)
plt.title('Average Daily Rates vs Months of the Year')
# Out:
# Text(0.5, 1.0, 'Average Daily Rates vs Months of the Year')

# %%
# Plotting the rate_per_stay with respect to years
bar_plotter(year)
plt.title('Average Daily Rates vs Years')
# Out:
# Text(0.5, 1.0, 'Average Daily Rates vs Years')

# %%
# To know the acutal visitor numbers, only bookings that were not canceled are included. 
resort_hotel = dataset.loc[(dataset["hotel"] == "Resort Hotel") & (dataset["is_canceled"] == 0)]
city_hotel = dataset.loc[(dataset["hotel"] == "City Hotel") & (dataset["is_canceled"] == 0)]

# %%
resort_guests_monthly = resort_hotel.groupby("arrival_date_month")["hotel"].count()
city_guests_monthly = city_hotel.groupby("arrival_date_month")["hotel"].count()

# %%
# finding the number of guests per month in each hotel type
resort_guest_data = pd.DataFrame({"month": list(resort_guests_monthly.index),
                    "hotel": "Resort hotel", 
                    "guests": list(resort_guests_monthly.values)})

city_guest_data = pd.DataFrame({"month": list(city_guests_monthly.index),
                    "hotel": "City hotel", 
                    "guests": list(city_guests_monthly.values)})
full_guest_data = pd.concat([resort_guest_data,city_guest_data], ignore_index=True)

# %%
# Plotting the data above to visualize the distribution
plotter()
sns.lineplot(x = "month", y="guests", hue="hotel", data=full_guest_data, 
             hue_order = ["City hotel", "Resort hotel"], size="hotel", sizes=(2.5, 2.5))
plt.title('Guests per Month')
# Out:
# Text(0.5, 1.0, 'Guests per Month')

# %%
# bar plot of the distribution
plotter()
sns.barplot(x = "month", y="guests", hue="hotel", data=full_guest_data,  hue_order = ["City hotel", "Resort hotel"])
plt.title('Guests per month')
# Out:
# Text(0.5, 1.0, 'Guests per month')

# %% [markdown]
#    ### Observation
#    From above it can be observed that the prices are higher (over 100/room) during months April to September but still more people travel during these months as the number of guests in City Hotels is over 2000 per months. The prices are lower in the winter months of October through March (less than 100) when the number of travelers decrease. Therefore, as expected we can say that the price of a hotel room is directly proportional to the number of guests. The prices of hotels increase as the demand increases.
#
#    ### Result:
#    In order to get cheap prices on hotels, it will be beneficial to make trips during the winter months.

# %% [markdown]
# ## Setup Phase (Project II)

# %% [markdown]
# ## Setup Phase

# %%
# Importing the necessary libraries
from sklearn.model_selection import train_test_split
from scipy.stats import ttest_ind
import random

# %%
#Create test and train partitions
data_train, data_test = train_test_split(dataset, test_size = 0.25, random_state = 7)

# %%
#Checking the shapes of our parititons
print('The shape of the training data is {}'.format(data_train.shape))
# Out:
# The shape of the training data is (56374, 29)

# %%
print('The shape of the test data is {}'.format(data_test.shape))
# Out:
# The shape of the test data is (18792, 29)

# %%
#Checking the mean of imporant numerical variables in our dataset in the 2 respective partitions
mean_of_adr_train = data_train['adr'].mean()
mean_of_adr_test = data_test['adr'].mean()

pd.DataFrame({'Data Type':['Train_adr','Test_adr'],
                             'mean':[mean_of_adr_train,mean_of_adr_test]})
# Out:
#    Data Type        mean
# 0  Train_adr   99.926590
# 1   Test_adr  100.170994

# %%
mean_of_rate_per_stay_train = data_train['rate_per_stay'].mean()
mean_of_rate_per_stay_test = data_test['rate_per_stay'].mean()

pd.DataFrame({'Data Type':['Train_rate_per_stay','Test_rate_per_stay'],
                             'mean':[mean_of_rate_per_stay_train,mean_of_rate_per_stay_test]})
# Out:
#              Data Type        mean
# 0  Train_rate_per_stay  345.238976
# 1   Test_rate_per_stay  347.688292

# %% [markdown]
# The paritions look good so far. Lets represent them again graphically based on the number of guests per month like we did above.

# %% [markdown]
# ### Visualization of the data split for cross validation

# %%
resort_hotel_train = data_train.loc[(data_train["hotel"] == "Resort Hotel") & (data_train["is_canceled"] == 0)]
city_hotel_train = data_train.loc[(data_train["hotel"] == "City Hotel") & (data_train["is_canceled"] == 0)]

# %%
resort_guests_monthly_train = resort_hotel_train.groupby("arrival_date_month")["hotel"].count()
city_guests_monthly_train = city_hotel_train.groupby("arrival_date_month")["hotel"].count()

# %%
resort_guest_data_train = pd.DataFrame({"month": list(resort_guests_monthly_train.index),
                    "hotel": "Resort hotel", 
                    "guests": list(resort_guests_monthly_train.values)})

city_guest_data_train = pd.DataFrame({"month": list(city_guests_monthly_train.index),
                    "hotel": "City hotel", 
                    "guests": list(city_guests_monthly_train.values)})
full_guest_data_train = pd.concat([resort_guest_data_train,city_guest_data_train], ignore_index=True)

# %%
# Visualizing the number of guests per month in training set
plotter()
sns.barplot(x = "month", y="guests", hue="hotel", data=full_guest_data_train,  hue_order = ["City hotel", "Resort hotel"])
plt.title('Guests per month in training set')
# Out:
# Text(0.5, 1.0, 'Guests per month in training set')

# %%
# Visualizing the number of guests per month in test data

resort_hotel_test = data_test.loc[(data_test["hotel"] == "Resort Hotel") & (data_test["is_canceled"] == 0)]
city_hotel_test  = data_test.loc[(data_test["hotel"] == "City Hotel") & (data_test["is_canceled"] == 0)]

# %%
resort_guests_monthly_test = resort_hotel_test.groupby("arrival_date_month")["hotel"].count()
city_guests_monthly_test = city_hotel_test.groupby("arrival_date_month")["hotel"].count()

# %%
resort_guest_data_test = pd.DataFrame({"month": list(resort_guests_monthly_test.index),
                    "hotel": "Resort hotel", 
                    "guests": list(resort_guests_monthly_test.values)})

city_guest_data_test = pd.DataFrame({"month": list(city_guests_monthly_test.index),
                    "hotel": "City hotel", 
                    "guests": list(city_guests_monthly_test.values)})
full_guest_data_test = pd.concat([resort_guests_monthly_test,city_guests_monthly_test], ignore_index=True)

# %%
plotter()
sns.barplot(x = "month", y="guests", hue="hotel", data=full_guest_data_train,  hue_order = ["City hotel", "Resort hotel"])
plt.title('Guests per month in testing set')
# Out:
# Text(0.5, 1.0, 'Guests per month in testing set')

# %% [markdown]
# #### Observation:
# It is clear from the two graphs that the partitions are very similar to each other and contain similar splits of variables needed to cluster the data.

# %%
#Takes any numerical variable, 'RATE' and data set
def clusterMonth(RATE,data_set):
    X_month = data_set[[RATE,'arrival_date_month']]
    Xz_month = pd.DataFrame(stats.zscore(X_month),columns=[RATE,'arrival_date_month'])
    kmeans_month = KMeans(n_clusters=2).fit(Xz_month)
    cluster_month = kmeans_month.labels_
    Cluster1_month = Xz_month.loc[cluster_month  == 0]
    Cluster2_month = Xz_month.loc[cluster_month  == 1]
    print(Cluster1_month.describe())
    print(Cluster2_month.describe())
    return Cluster1_month, Cluster2_month

# %%
#K-means clusering model generation on testing set
cluster_test = clusterMonth('rate_per_stay',data_test)
# Out:
#        rate_per_stay  arrival_date_month
# count   10383.000000        10383.000000
# mean        0.235768            0.756121
# std         1.200205            0.570713
# min        -1.062802           -1.752630
# 25%        -0.549265            0.157611
# 50%        -0.132934            0.794358
# 75%         0.623418            1.112732
# max        22.138066            1.749478
#        rate_per_stay  arrival_date_month
# count    8409.000000         8409.000000
# mean       -0.291115           -0.933620
# std         0.550387            0.505043
# min        -1.062802           -1.752630
# 25%        -0.726558           -1.434256
# 50%        -0.375030           -0.797509
# 75%         0.002542           -0.479136
# max         4.252306            0.157611

# %%
#K-means clusering model generation on training set
cluster_train = clusterMonth('rate_per_stay',data_train)
# Out:
#        rate_per_stay  arrival_date_month
# count   25660.000000        25660.000000
# mean       -0.298168           -0.917146
# std         0.557165            0.514987
# min        -1.272668           -1.752400
# 25%        -0.738136           -1.435710
# 50%        -0.392806           -0.802331
# 75%         0.008591           -0.485641
# max         4.627718            0.147739
#        rate_per_stay  arrival_date_month
# count   30714.000000        30714.000000
# mean        0.249104            0.766229
# std         1.199928            0.569251
# min        -1.074163           -1.435710
# 25%        -0.545232            0.464429
# 50%        -0.115553            0.781118
# 75%         0.657309            1.097808
# max        19.554165            1.731188

# %%
#Validate cluser results with t-test, other tests if needed

# %%
ttest_ind(cluster_train[0].mean(),cluster_test[0].mean())
# Out:
# Ttest_indResult(statistic=-2.72951933704293, pvalue=0.11210025048367345)

# %%
ttest_ind(cluster_train[1].mean(),cluster_test[1].mean())
# Out:
# Ttest_indResult(statistic=2.7160193482864785, pvalue=0.11303509993069505)

# %% [markdown]
# Result from the T-test are as expected, with very small p_values showing that the correlation is fairly strong as expected.

# %% [markdown]
# Now lets generate another set of models with using the variable 'adr' and 'arrival_date_month'

# %%
cluster_train_adr = clusterMonth('adr',data_train)
# Out:
#                 adr  arrival_date_month
# count  22936.000000        22936.000000
# mean      -0.433250           -0.986758
# std        0.659373            0.497203
# min       -2.155792           -1.752400
# 25%       -0.829951           -1.435710
# 50%       -0.420315           -1.119020
# 75%       -0.039069           -0.485641
# max        2.759434            0.464429
#                 adr  arrival_date_month
# count  33438.000000        33438.000000
# mean       0.297178            0.676843
# std        1.081982            0.624804
# min       -2.026412           -1.435710
# 25%       -0.471621            0.147739
# 50%        0.179944            0.781118
# 75%        0.893765            1.097808
# max        8.315882            1.731188

# %%
cluster_test_adr = clusterMonth('adr',data_test)
# Out:
#                adr  arrival_date_month
# count  7678.000000         7678.000000
# mean     -0.421290           -0.988127
# std       0.664739            0.494370
# min      -2.049086           -1.752630
# 25%      -0.821733           -1.434256
# 50%      -0.412615           -1.115883
# 75%      -0.037966           -0.479136
# max       2.614855            0.475985
#                 adr  arrival_date_month
# count  11114.000000        11114.000000
# mean       0.291044            0.682638
# std        1.085541            0.617678
# min       -2.049086           -1.752630
# 25%       -0.484211            0.157611
# 50%        0.166695            0.475985
# 75%        0.886640            1.112732
# max        5.887796            1.749478

# %%
ttest_ind(cluster_train_adr[0].mean(),cluster_test_adr[0].mean())
# Out:
# Ttest_indResult(statistic=-0.01336862981549221, pvalue=0.9905473735368302)

# %%
ttest_ind(cluster_train_adr[1].mean(),cluster_test_adr[1].mean())
# Out:
# Ttest_indResult(statistic=0.0006211493600059682, pvalue=0.9995607811177757)

# %% [markdown]
# To note, running 'adr' and 'arrival_date_month' results in a p_value of 0.0731 vs a p_value of 0.1119, so we can see that using 'adr' gives better performance statistically.

# %% [markdown]
# ## Creating a model with linear regression to predict prices

# %%
import statsmodels.api as sm
from sklearn import metrics as met

# %%
# Selecting the attributes that could be good predictors in the linear regression implementation
X_train = pd.DataFrame(data_train[['lead_time','arrival_date_year','arrival_date_month',
                         'arrival_date_week_number','stays_in_weekend_nights',
                        'days_in_waiting_list']])

# Average daily rate be the target variable
y_train = pd.DataFrame(data_train['adr'])


X_test = pd.DataFrame(data_test[['lead_time','arrival_date_year','arrival_date_month',
                         'arrival_date_week_number','stays_in_weekend_nights',
                        'days_in_waiting_list']])

# Average daily rate be the target variable
y_test = pd.DataFrame(data_test['adr'])

# %%
# Addition of a constant for the implementation
X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# %%
# Checking the data after constant addition
X_train.head()
# Out:
#         const  lead_time  arrival_date_year  arrival_date_month  \
# 112665    1.0      151.0             2017.0                 5.0
# 97060     1.0      240.0             2016.0                 9.0
# 98259     1.0       35.0             2016.0                 9.0
# 95514     1.0      320.0             2016.0                 8.0
# 16902     1.0        0.0             2016.0                 1.0
#
#         arrival_date_week_number  stays_in_weekend_nights  \
# 112665                      21.0                      0.0
# 97060                       37.0                      1.0
# 98259                       40.0                      2.0
# 95514                       34.0                      0.0
# 16902                        4.0                      0.0
#
#         days_in_waiting_list
# 112665                   0.0
# 97060                    0.0
# 98259                    0.0
# 95514                    0.0
# 16902                    0.0

# %%
X_test.head()
# Out:
#        const  lead_time  arrival_date_year  arrival_date_month  \
# 26850    1.0       21.0             2016.0                 8.0
# 32965    1.0        6.0             2017.0                 2.0
# 99634    1.0      335.0             2016.0                10.0
# 36233    1.0      228.0             2017.0                 5.0
# 99542    1.0        2.0             2016.0                10.0
#
#        arrival_date_week_number  stays_in_weekend_nights  days_in_waiting_list
# 26850                      33.0                      0.0                   0.0
# 32965                       6.0                      0.0                   0.0
# 99634                      42.0                      0.0                   0.0
# 36233                      18.0                      2.0                   0.0
# 99542                      42.0                      0.0                   0.0

# %%
# checking the shape of the train data
train_predictors_shape = X_train.shape
print('The shape of the predictors in training data is {}'.format(train_predictors_shape))
# Out:
# The shape of the predictors in training data is (56374, 7)

# %%
# Checking the shape of of the target variable
train_target_shape = y_train.shape
print('The shape of the target in training data is {}'.format(train_target_shape))
# Out:
# The shape of the target in training data is (56374, 1)

# %%
# checking the shape of the data
test_predictors_shape = X_test.shape
print('The shape of the predictors in test data is {}'.format(test_predictors_shape))
# Out:
# The shape of the predictors in test data is (18792, 7)

# %%
# checking the shape of the test data
test_target_shape = y_test.shape
print('The shape of the target in test data is {}'.format(test_target_shape))
# Out:
# The shape of the target in test data is (18792, 1)

# %%
# training the model with linear regression
model_train = sm.OLS(y_train,X_train).fit()
model_test = sm.OLS(y_test,X_test).fit()

# %%
# Checking the OLS Regression results
model_train.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    adr   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     868.1
# Date:                Wed, 29 Apr 2020   Prob (F-statistic):               0.00
# Time:                        19:48:13   Log-Likelihood:            -2.9726e+05
# No. Observations:               56374   AIC:                         5.945e+05
# Df Residuals:                   56367   BIC:                         5.946e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -4.594e+04    699.991    -65.635      0.000   -4.73e+04   -4.46e+04
# lead_time                   -0.0266      0.002    -11.415      0.000      -0.031      -0.022
# arrival_date_year           22.8239      0.347     65.758      0.000      22.144      23.504
# arrival_date_month           2.5604      0.658      3.889      0.000       1.270       3.851
# arrival_date_week_number     0.4184      0.151      2.777      0.005       0.123       0.714
# stays_in_weekend_nights      1.7274      0.206      8.402      0.000       1.324       2.130
# days_in_waiting_list        -0.0488      0.014     -3.587      0.000      -0.076      -0.022
# ==============================================================================
# Omnibus:                     7454.877   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15504.222
# Skew:                           0.817   Prob(JB):                         0.00
# Kurtosis:                       4.982   Cond. No.                     7.11e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.11e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Linear Regression for the test set
model_test.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    adr   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     280.8
# Date:                Wed, 29 Apr 2020   Prob (F-statistic):               0.00
# Time:                        19:48:14   Log-Likelihood:                -98949.
# No. Observations:               18792   AIC:                         1.979e+05
# Df Residuals:                   18785   BIC:                         1.980e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                    -4.425e+04   1199.867    -36.882      0.000   -4.66e+04   -4.19e+04
# lead_time                   -0.0283      0.004     -7.126      0.000      -0.036      -0.021
# arrival_date_year           21.9854      0.595     36.953      0.000      20.819      23.152
# arrival_date_month           3.6709      1.131      3.245      0.001       1.454       5.888
# arrival_date_week_number     0.1443      0.259      0.557      0.577      -0.363       0.652
# stays_in_weekend_nights      1.8761      0.348      5.390      0.000       1.194       2.558
# days_in_waiting_list        -0.0585      0.025     -2.383      0.017      -0.107      -0.010
# ==============================================================================
# Omnibus:                     2232.396   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4179.119
# Skew:                           0.780   Prob(JB):                         0.00
# Kurtosis:                       4.704   Cond. No.                     7.09e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.09e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Conclusions
#         predictors lead_time,arrival_date_year,arrival_date_month,arrival_date_week_number,stays_in_weekend_nights, and days_in_waiting_list are in the coef columns.
#
#         P >|t| is between -0.05 and 0.05 for all attributes in the training set referring that all these predictors variables belongs in the model.
#
#         arrival_date_week_number variable does not belong in the model since it doesnot falls in the threshold in the training set.
#
#         Therefore, we have to tweak and tune our model by removing arrival_date_week_number variable from the predictors which will decrease the model complexity.

# %% [markdown]
# ## Second phase of Linear Regression

# %%
# Selecting the attributes that could be good predictors in the linear regression implementation
X_train_2 = pd.DataFrame(data_train[['lead_time','arrival_date_year','arrival_date_month',
                         'stays_in_weekend_nights',
                        'days_in_waiting_list']])

# Average daily rate be the target variable
y_train_2 = pd.DataFrame(data_train['adr'])


X_test_2 = pd.DataFrame(data_test[['lead_time','arrival_date_year','arrival_date_month',
                         'stays_in_weekend_nights',
                        'days_in_waiting_list']])

# Average daily rate be the target variable
y_test_2 = pd.DataFrame(data_test['adr'])

# Addition of a constant for the implementation
X_train_2 = sm.add_constant(X_train_2)
X_test_2 = sm.add_constant(X_test_2)

# Checking the data after constant addition
X_train_2.head()

X_test_2.head()

# checking the shape of the train data
train_predictors_shape_2 = X_train_2.shape
print('The shape of the predictors in training data is {}'.format(train_predictors_shape_2))

# Checking the shape of of the target variable
train_target_shape_2 = y_train_2.shape
print('The shape of the target in training data is {}'.format(train_target_shape_2))

# checking the shape of the data
test_predictors_shape_2 = X_test_2.shape
print('The shape of the predictors in test data is {}'.format(test_predictors_shape_2))

# checking the shape of the test data
test_target_shape_2 = y_test_2.shape
print('The shape of the target in test data is {}'.format(test_target_shape_2))

# training the model with linear regression
model_train_2 = sm.OLS(y_train_2,X_train_2).fit()
model_test_2 = sm.OLS(y_test_2,X_test_2).fit()

# Checking the OLS Regression results
model_train_2.summary()
# Out:
# The shape of the predictors in training data is (56374, 6)
# The shape of the target in training data is (56374, 1)
# The shape of the predictors in test data is (18792, 6)
# The shape of the target in test data is (18792, 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    adr   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     1040.
# Date:                Wed, 29 Apr 2020   Prob (F-statistic):               0.00
# Time:                        19:48:18   Log-Likelihood:            -2.9726e+05
# No. Observations:               56374   AIC:                         5.945e+05
# Df Residuals:                   56368   BIC:                         5.946e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                   -4.562e+04    690.005    -66.110      0.000    -4.7e+04   -4.43e+04
# lead_time                  -0.0266      0.002    -11.385      0.000      -0.031      -0.022
# arrival_date_year          22.6610      0.342     66.237      0.000      21.990      23.332
# arrival_date_month          4.3764      0.076     57.679      0.000       4.228       4.525
# stays_in_weekend_nights     1.7326      0.206      8.428      0.000       1.330       2.136
# days_in_waiting_list       -0.0479      0.014     -3.518      0.000      -0.075      -0.021
# ==============================================================================
# Omnibus:                     7464.707   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15539.927
# Skew:                           0.818   Prob(JB):                         0.00
# Kurtosis:                       4.985   Cond. No.                     7.01e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.01e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Linear Regression for the test set
model_test_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    adr   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     337.0
# Date:                Wed, 29 Apr 2020   Prob (F-statistic):               0.00
# Time:                        19:48:35   Log-Likelihood:                -98949.
# No. Observations:               18792   AIC:                         1.979e+05
# Df Residuals:                   18786   BIC:                         1.980e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                   -4.414e+04   1181.921    -37.344      0.000   -4.65e+04   -4.18e+04
# lead_time                  -0.0283      0.004     -7.124      0.000      -0.036      -0.021
# arrival_date_year          21.9282      0.586     37.418      0.000      20.780      23.077
# arrival_date_month          4.2972      0.131     32.900      0.000       4.041       4.553
# stays_in_weekend_nights     1.8762      0.348      5.390      0.000       1.194       2.558
# days_in_waiting_list       -0.0580      0.025     -2.366      0.018      -0.106      -0.010
# ==============================================================================
# Omnibus:                     2233.524   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4181.342
# Skew:                           0.780   Prob(JB):                         0.00
# Kurtosis:                       4.705   Cond. No.                     6.98e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.98e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Visual representation of the model
from statsmodels.graphics.regressionplots import plot_partregress_grid
import statsmodels.formula.api as smf
fig = plt.figure(figsize=(20, 15))
plot_partregress_grid(model_train_2, fig=fig)
plt.show()

# %% [markdown]
# ### Conclusions
#         predictors lead_time,arrival_date_year,arrival_date_month,stays_in_weekend_nights, and days_in_waiting_list are in the coef columns.
#
#         P >|t| is between -0.05 and 0.05 for all attributes in the training set as well as test set referring that all these predictors variables belongs in the model.
#
#
# Therefore, since all predictors have significant P-value, our training model is $$Average Daily Rate = -45620 -0.0266*lead time +22.6610*arrival date year + 4.3764*arrival date month +1.7326*stays in weekend nights -0.0479*days in waiting list$$
