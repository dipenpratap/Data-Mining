# %%
# Importing the libraries
import pandas as pd
import numpy as np
import statistics as st

# %%
# Importing the dataset
dataset = pd.read_csv('churn')
dataset
# Out:
#      State  Account Length  Area Code     Phone Intl Plan VMail Plan  \
# 0       KS             128        415  382-4657        no        yes
# 1       OH             107        415  371-7191        no        yes
# 2       NJ             137        415  358-1921        no         no
# 3       OH              84        408  375-9999       yes         no
# 4       OK              75        415  330-6626       yes         no
# ...    ...             ...        ...       ...       ...        ...
# 3328    AZ             192        415  414-4276        no        yes
# 3329    WV              68        415  370-3271        no         no
# 3330    RI              28        510  328-8230        no         no
# 3331    CT             184        510  364-6381       yes         no
# 3332    TN              74        415  400-4344        no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# 0                25     265.1        110       45.07  ...       16.78
# 1                26     161.6        123       27.47  ...       16.62
# 2                 0     243.4        114       41.38  ...       10.30
# 3                 0     299.4         71       50.90  ...        5.26
# 4                 0     166.7        113       28.34  ...       12.61
# ...             ...       ...        ...         ...  ...         ...
# 3328             36     156.2         77       26.55  ...       18.32
# 3329              0     231.1         57       39.29  ...       13.04
# 3330              0     180.8        109       30.74  ...       24.55
# 3331              0     213.8        105       36.35  ...       13.57
# 3332             25     234.4        113       39.85  ...       22.60
#
#       Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0          244.7           91         11.01       10.0           3
# 1          254.4          103         11.45       13.7           3
# 2          162.6          104          7.32       12.2           5
# 3          196.9           89          8.86        6.6           7
# 4          186.9          121          8.41       10.1           3
# ...          ...          ...           ...        ...         ...
# 3328       279.1           83         12.56        9.9           6
# 3329       191.3          123          8.61        9.6           4
# 3330       191.9           91          8.64       14.1           6
# 3331       139.2          137          6.26        5.0          10
# 3332       241.4           77         10.86       13.7           4
#
#       Intl Charge  CustServ Calls  Old Churn  Churn
# 0            2.70               1     False.  False
# 1            3.70               1     False.  False
# 2            3.29               0     False.  False
# 3            1.78               2     False.  False
# 4            2.73               3     False.  False
# ...           ...             ...        ...    ...
# 3328         2.67               2     False.  False
# 3329         2.59               3     False.  False
# 3330         3.81               2     False.  False
# 3331         1.35               2     False.  False
# 3332         3.70               0     False.  False
#
# [3333 rows x 22 columns]

# %% [markdown]
#  1. Using the churn data set, determine how many records need to be resampled in order to have 20% of the rebalanced dataset have true Churn variable values. Create the rebalanced data set and confirm that the new data set has 20% true Churn variable values.

# %%
# Balancing the data to get 20% of the churn variables to have true values
n = dataset.shape[0]
Churn = dataset['Churn']
false,true = Churn.value_counts()

# %%
# Calculating the number of records to be resampled
num_to_add = int((0.2*n-true)/(1-0.2))
print('The number of records to be resampled is {}.'.format(num_to_add))
# Out:
# The number of records to be resampled is 229.

# %%
to_resample_loc = dataset.loc[dataset['Churn']==True]
to_resample_loc
# Out:
#      State  Account Length  Area Code     Phone Intl Plan VMail Plan  \
# 10      IN              65        415  329-6603        no         no
# 15      NY             161        415  351-7269        no         no
# 21      CO              77        408  393-7984        no         no
# 33      AZ              12        408  360-1596        no         no
# 41      MD             135        408  383-6029       yes        yes
# ...    ...             ...        ...       ...       ...        ...
# 3301    CA              84        415  417-1488        no         no
# 3304    IL              71        510  330-7137       yes         no
# 3320    GA             122        510  411-5677       yes         no
# 3322    MD              62        408  409-1856        no         no
# 3323    IN             117        415  362-5899        no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# 10                0     129.1        137       21.95  ...       19.42
# 15                0     332.9         67       56.59  ...       27.01
# 21                0      62.4         89       10.61  ...       14.44
# 33                0     249.6        118       42.43  ...       21.45
# 41               41     173.1         85       29.43  ...       17.33
# ...             ...       ...        ...         ...  ...         ...
# 3301              0     280.0        113       47.60  ...       17.19
# 3304              0     186.1        114       31.64  ...       16.88
# 3320              0     140.0        101       23.80  ...       16.69
# 3322              0     321.1        105       54.59  ...       22.57
# 3323              0     118.4        126       20.13  ...       21.19
#
#       Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 10         208.8          111          9.40       12.7           6
# 15         160.6          128          7.23        5.4           9
# 21         209.6           64          9.43        5.7           6
# 33         280.2           90         12.61       11.8           3
# 41         122.2           78          5.50       14.6          15
# ...          ...          ...           ...        ...         ...
# 3301       156.8          103          7.06       10.4           4
# 3304       206.5           80          9.29       13.8           5
# 3320       120.1          133          5.40        9.7           4
# 3322       180.5           72          8.12       11.5           2
# 3323       227.0           56         10.22       13.6           3
#
#       Intl Charge  CustServ Calls  Old Churn  Churn
# 10           3.43               4      True.   True
# 15           1.46               4      True.   True
# 21           1.54               5      True.   True
# 33           3.19               1      True.   True
# 41           3.94               0      True.   True
# ...           ...             ...        ...    ...
# 3301         2.81               0      True.   True
# 3304         3.73               4      True.   True
# 3320         2.62               4      True.   True
# 3322         3.11               4      True.   True
# 3323         3.67               5      True.   True
#
# [483 rows x 22 columns]

# %%
# Creating the rebalanced dataset
new_samples = to_resample_loc.sample(n=num_to_add,replace = True)
print('The new samples for rebalance are: ')
new_samples
# Out:
# The new samples for rebalance are:
#      State  Account Length  Area Code     Phone Intl Plan VMail Plan  \
# 2142    MT             100        415  385-7148        no         no
# 2142    MT             100        415  385-7148        no         no
# 3226    ME             100        510  351-2815        no         no
# 521     SC              88        510  394-8402        no         no
# 2581    NY             123        415  329-6731        no         no
# ...    ...             ...        ...       ...       ...        ...
# 2324    LA             124        510  348-4316        no         no
# 2536    CT             119        408  344-5181        no         no
# 1842    WA              97        408  373-8908        no         no
# 1337    WY              97        510  346-1629       yes         no
# 1532    CA             103        415  402-6744        no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# 2142              0      96.5         86       16.41  ...       17.87
# 2142              0      96.5         86       16.41  ...       17.87
# 3226              0     264.5        117       44.97  ...       16.49
# 521               0      73.3         86       12.46  ...       13.72
# 2581              0     123.2        104       20.94  ...       16.15
# ...             ...       ...        ...         ...  ...         ...
# 2324              0     143.3        120       24.36  ...       19.61
# 2536              0     294.2        100       50.01  ...       19.76
# 1842              0     276.1         82       46.94  ...       17.09
# 1337              0     236.9        107       40.27  ...       13.40
# 1532             18     149.9         84       25.48  ...       14.53
#
#       Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 2142       146.4          106          6.59       12.5           3
# 2142       146.4          106          6.59       12.5           3
# 3226       262.7          111         11.82        7.5           4
# 521        239.6           76         10.78        8.2           3
# 2581       170.3           95          7.66       12.9           5
# ...          ...          ...           ...        ...         ...
# 2324       214.3           91          9.64        7.8           2
# 2536       195.0           64          8.78        9.0           1
# 1842       231.3           73         10.41        8.9           4
# 1337       241.0          120         10.85        7.3           2
# 1532       171.5          112          7.72       11.5           7
#
#       Intl Charge  CustServ Calls  Old Churn  Churn
# 2142         3.38               1      True.   True
# 2142         3.38               1      True.   True
# 3226         2.03               2      True.   True
# 521          2.21               4      True.   True
# 2581         3.48               4      True.   True
# ...           ...             ...        ...    ...
# 2324         2.11               4      True.   True
# 2536         2.43               0      True.   True
# 1842         2.40               0      True.   True
# 1337         1.97               0      True.   True
# 1532         3.11               0      True.   True
#
# [229 rows x 22 columns]

# %%
# Concatenating the samples with original dataset
dataset_rebal = pd.concat([dataset,new_samples])
print('The new rebalanced dataset is: ')
dataset_rebal
# Out:
# The new rebalanced dataset is:
#      State  Account Length  Area Code     Phone Intl Plan VMail Plan  \
# 0       KS             128        415  382-4657        no        yes
# 1       OH             107        415  371-7191        no        yes
# 2       NJ             137        415  358-1921        no         no
# 3       OH              84        408  375-9999       yes         no
# 4       OK              75        415  330-6626       yes         no
# ...    ...             ...        ...       ...       ...        ...
# 2324    LA             124        510  348-4316        no         no
# 2536    CT             119        408  344-5181        no         no
# 1842    WA              97        408  373-8908        no         no
# 1337    WY              97        510  346-1629       yes         no
# 1532    CA             103        415  402-6744        no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# 0                25     265.1        110       45.07  ...       16.78
# 1                26     161.6        123       27.47  ...       16.62
# 2                 0     243.4        114       41.38  ...       10.30
# 3                 0     299.4         71       50.90  ...        5.26
# 4                 0     166.7        113       28.34  ...       12.61
# ...             ...       ...        ...         ...  ...         ...
# 2324              0     143.3        120       24.36  ...       19.61
# 2536              0     294.2        100       50.01  ...       19.76
# 1842              0     276.1         82       46.94  ...       17.09
# 1337              0     236.9        107       40.27  ...       13.40
# 1532             18     149.9         84       25.48  ...       14.53
#
#       Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 0          244.7           91         11.01       10.0           3
# 1          254.4          103         11.45       13.7           3
# 2          162.6          104          7.32       12.2           5
# 3          196.9           89          8.86        6.6           7
# 4          186.9          121          8.41       10.1           3
# ...          ...          ...           ...        ...         ...
# 2324       214.3           91          9.64        7.8           2
# 2536       195.0           64          8.78        9.0           1
# 1842       231.3           73         10.41        8.9           4
# 1337       241.0          120         10.85        7.3           2
# 1532       171.5          112          7.72       11.5           7
#
#       Intl Charge  CustServ Calls  Old Churn  Churn
# 0            2.70               1     False.  False
# 1            3.70               1     False.  False
# 2            3.29               0     False.  False
# 3            1.78               2     False.  False
# 4            2.73               3     False.  False
# ...           ...             ...        ...    ...
# 2324         2.11               4      True.   True
# 2536         2.43               0      True.   True
# 1842         2.40               0      True.   True
# 1337         1.97               0      True.   True
# 1532         3.11               0      True.   True
#
# [3562 rows x 22 columns]

# %%
new_n = dataset_rebal.shape[0]
new_false,new_true = dataset_rebal['Churn'].value_counts()
new_true_per = np.round((new_true/new_n)*100,decimals=1)
print('The new dataset has {} percent {} Churn instances.'.format(new_true_per,'True'))
# Out:
# The new dataset has 20.0 percent True Churn instances.

# %% [markdown]
# 2. Partition the rebalanced data set so that 67% of the records are included in the training data set and 33% are included in the
# test data set. Use a bar graph to confirm the proportions. Validate the training and test data sets by testing for the difference
# in the training and test means using Day.Mins (t-test) and the Z-test on the Churn variable. Try forming new training and test
# sets if there is enough evidence to reject the null hypothesis.

# %%
import statistics as stat
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
train_data,test_data = train_test_split(dataset_rebal,test_size = 0.33,random_state = 7)

# %%
print('The training dataset is: ')
train_data
# Out:
# The training dataset is:
#      State  Account Length  Area Code     Phone Intl Plan VMail Plan  \
# 2737    ID             109        415  384-9682        no         no
# 108     CO             141        415  371-4306        no        yes
# 2799    WV              70        415  402-2072        no         no
# 1643    WI             107        408  392-5296        no         no
# 3053    CA              82        415  394-9220        no         no
# ...    ...             ...        ...       ...       ...        ...
# 1603    WV              54        510  353-2450        no        yes
# 2550    AR              87        408  390-4789        no         no
# 537     UT             190        415  398-9870        no        yes
# 1220    NV             180        510  351-1382        no         no
# 175     NE              94        415  377-1765        no         no
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Charge  \
# 2737              0     184.1        143       31.30  ...       17.99
# 108              32     148.6         91       25.26  ...       11.14
# 2799              0     214.8         87       36.52  ...       11.14
# 1643              0     134.0        104       22.78  ...       14.83
# 3053              0     199.3        112       33.88  ...       16.44
# ...             ...       ...        ...         ...  ...         ...
# 1603             33     112.0         90       19.04  ...       17.68
# 2550              0     185.8        119       31.59  ...       16.35
# 537              22     166.5         93       28.31  ...       15.56
# 1220              0     139.0         96       23.63  ...       19.12
# 175               0     252.6        104       42.94  ...       14.37
#
#       Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 2737       243.0          116         10.93        9.9           2
# 108        219.4          142          9.87       10.1           1
# 2799       216.9          104          9.76        9.4           3
# 1643       311.1           79         14.00        7.3           3
# 3053       254.4          117         11.45        7.0          10
# ...          ...          ...           ...        ...         ...
# 1603       150.3           83          6.76       11.3           4
# 2550       200.0           96          9.00        6.6           4
# 537        121.0          102          5.44        8.5           3
# 1220       170.8          118          7.69       15.7           5
# 175        170.9          106          7.69       11.1           7
#
#       Intl Charge  CustServ Calls  Old Churn  Churn
# 2737         2.67               1     False.  False
# 108          2.73               1     False.  False
# 2799         2.54               3     False.  False
# 1643         1.97               3     False.  False
# 3053         1.89               0     False.  False
# ...           ...             ...        ...    ...
# 1603         3.05               2     False.  False
# 2550         1.78               1     False.  False
# 537          2.30               0     False.  False
# 1220         4.24               2     False.  False
# 175          3.00               2     False.  False
#
# [2386 rows x 22 columns]

# %%
# Validation of training dataset percentage
train_data_size = train_data.shape[0]
test_data_size = test_data.shape[0]
train_per = int(np.ceil((train_data_size/new_n)*100))
test_per = int(np.ceil((test_data_size/new_n)*100))
print('The percentage of training dataset is {}%'.format(train_per))
print('The percentage of test dataset is {}%'.format(test_per))
# Out:
# The percentage of training dataset is 67%
# The percentage of test dataset is 34%

# %%
# Plotting the bar graph
plt.figure()
plt.bar(['Train_data','Test_data'], [train_per,test_per], align='center', alpha=1)
plt.grid()
plt.xlabel('Dataset')
plt.ylabel('Percentage %')
plt.figure()
plt.bar(['Train_data','Test_data'], [train_data_size,test_data_size], align='center', alpha=1)
plt.grid()
plt.xlabel('Dataset')
plt.ylabel('# of instances')
# Out:
# Text(0, 0.5, '# of instances')

# %% [markdown]
# # Part 2 of the problem
# """Validate the training and test data sets by testing for the difference
# in the training and test means using Day.Mins (t-test) and the Z-test on the Churn variable. Try forming new training and test
# sets if there is enough evidence to reject the null hypothesis.
# """

# %%
# finding the mean and standard deviation of training data using Day_mins
day_mins_train = train_data['Day Mins']
mean_train_day_mins = st.mean(day_mins_train)
sd_train_day_mins =st.stdev(day_mins_train)


# finding the mean and standard deviation of test data using Day Mins
day_mins_test = test_data['Day Mins']
mean_test_day_mins = st.mean(day_mins_test)
sd_test_day_mins = st.stdev(day_mins_test)

# Number of isntances in the train and test data
train_n = train_data.shape[0]
test_n = test_data.shape[0]


s1_n1 = (sd_train_day_mins**2)/train_n
s2_n2 = (sd_test_day_mins**2)/test_n



t_Test_values = pd.DataFrame({'Data Type':['Train','Test'],'n':[train_n,test_n],
                             'mean':[mean_train_day_mins,mean_test_day_mins],
                             'Standard Deviation':[sd_train_day_mins,sd_test_day_mins]})

print('The values required for the calculation of t_Test value are: ')
t_Test_values
# Out:
# The values required for the calculation of t_Test value are:
#   Data Type     n        mean  Standard Deviation
# 0     Train  2386  181.461190           55.913346
# 1      Test  1176  180.619983           55.177648

# %%
t_Test_val = (mean_train_day_mins - mean_test_day_mins)/np.sqrt(s1_n1+s2_n2)
print('The t_Test value is {}'.format(t_Test_val))
# Out:
# The t_Test value is 0.4260060172290213

# %%
# Z-Test on the Churn variable

"""
For a flag variable (like no/yes) we need the two-sample Z test for the
difference in proportions
Therefore we are going to perform a Z-test on the Churn variable as it is a flag variable that indicates either True 
or False"""
# Out:
# '\nFor a flag variable (like no/yes) we need the two-sample Z test for the\ndifference in proportions\nTherefore we are going to perform a Z-test on the Churn variable as it is a flag variable that indicates either True \nor False'

# %%
train_churn = train_data['Churn']
test_churn = test_data['Churn']

# Getting the counts of true or false
false_train,true_train = train_churn.value_counts()
false_test,true_test = test_churn.value_counts()

# Lets proceed with true data
p_1 = true_train/train_n
p_2 = true_test/test_n
p_pooled = (true_train+true_test)/(train_n+test_n)
A = (1/train_n)+(1/test_n)
z_data = (p_1-p_2)/(np.sqrt(p_pooled*(1-p_pooled)*A))

# %%
z_data
# Out:
# 1.164251150718338

# %%
train_churn.value_counts()
# Out:
# False    1896
# True      490
# Name: Churn, dtype: int64
